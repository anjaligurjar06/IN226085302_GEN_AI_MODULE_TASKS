# %%
import os
# Disable ALL progress bars
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"
os.environ["DISABLE_TQDM"] = "1"
from transformers.utils import logging
logging.set_verbosity_error()

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers.utils import logging
logging.set_verbosity_error()

# %%
import logging
from transformers import logging as transformers_logging
transformers_logging.set_verbosity_error()

# %%
# !pip install transformers torch --quiet

# %%
# Standard library imports
import warnings
warnings.filterwarnings('ignore')  # Suppress unnecessary warnings
import torch
# Choose the Qwen 2.5 1.5B Instruct model
model_name = "Qwen/Qwen2.5-1.5B-Instruct"
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Load model with automatic dtype and device placement
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
model.eval()
print("Model loaded successfully.")
print("Device map:", model.hf_device_map if hasattr(model, "hf_device_map") else "Single device")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Model loaded successfully.
# Device map: Single device

# %%
def generate_reply(chat_history, user_message, max_new_tokens=256):
    # Append the new user message to the history
    chat_history.append({"role": "user", "content": user_message})
    # Apply Qwen chat template to convert messages into a single text prompt
    prompt_text = tokenizer.apply_chat_template(
        chat_history,
        tokenize=False,
        add_generation_prompt=True,  # model expects a generation prompt
    )
    # Tokenize the prompt
    inputs = tokenizer(
        [prompt_text],
        return_tensors="pt"
    ).to(model.device)
    # Generate the model output
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            repetition_penalty=1.05
        )

    # Extract only the newly generated tokens
    generated_ids = output_ids[0, inputs["input_ids"].shape[1]:]
    # Decode the assistant's reply
    assistant_reply = tokenizer.decode(
        generated_ids,
        skip_special_tokens=True
    ).strip()
    # Append assistant reply to history
    chat_history.append({"role": "assistant", "content": assistant_reply})
    return chat_history, assistant_reply

# %%
def run_chatbot():
    print("Chatbot: Hello! I am your AI assistant. How can I help you today?")
    # Initialize chat history with a system message to set behavior
    chat_history = [
        {
            "role": "system",
            "content": "You are a helpful, concise AI assistant. Answer clearly and politely."
        }
    ]
    while True:
        user_input = input("User: ").strip()

        # Exit condition
        if user_input.lower() in ["exit", "quit"]:
            print("Chatbot: Goodbye! Have a great day.")
            break

        # Skip empty input
        if not user_input:
            print("Chatbot: Please type something so I can respond.")
            continue
        # Generate reply from the model
        chat_history = chat_history[-6:]
        print("Chatbot: Thinking...")
        chat_history, assistant_reply = generate_reply(chat_history, user_input)
        # Basic safety: fallback message if reply is empty
        if assistant_reply == "":
            assistant_reply = "I'm not sure how to respond to that yet, but I'm learning."
        print("Chatbot:", assistant_reply)
run_chatbot()
# Out:
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# User: what is computer
# Chatbot: Thinking...
# Chatbot: A computer is an electronic device that can process information and perform tasks automatically. It consists of hardware (physical components) and software (instructions that tell the hardware how to work). Computers store and manipulate data using circuits and algorithms, and they can be used for a wide range of purposes including computing, communication, entertainment, and automation.
# User: who invented computer
# Chatbot: Thinking...
# Chatbot: The history of computers dates back many centuries, with early mechanical devices like the abacus and the astrolabe. However, the modern electronic computer as we know it today was largely developed in the mid-20th century.
#
# Key milestones include:
#
# 1. Charles Babbage's Analytical Engine (1837): An early mechanical general-purpose computer concept.
# 2. Herman Hollerith's tabulator (1896): A precursor to modern data processing machines.
# 3. John Atanasoff and Clifford Berry's Electronic Numerical Integrator and Computer (ENIAC) (1945): The first general-purpose electronic computer.
# 4. John von Neumann's design of the stored-program computer architecture (1945).
# 5. IBM's introduction of the IBM 360 series (1964): The first mass-produced, commercially successful general-purpose computer.
#
# These developments collectively led to the widespread use of computers in various fields such as science, business, and entertainment.
# User: what is deep learning
# Chatbot: Thinking...
# Chatbot: Deep learning is a subset of machine learning inspired by the structure and function of the brain called artificial neural networks. It involves training models on large amounts of data to recognize patterns and make predictions or decisions based on those patterns. Here are some key aspects of deep learning:
#
# 1. **Neural Networks**: These are composed of layers that process information. Each layer extracts increasingly abstract features from the input data.
#
# 2. **Backpropagation**: This is a method used to adjust the weights of the neural network during training, allowing the model to learn from its mistakes.
#
# 3. **Convolutional Neural Networks (CNNs)**: Specifically designed for image recognition tasks, CNNs use convolutional layers to detect local patterns in images.
#
# 4. **Recurrent Neural Networks (RNNs)**: These are particularly useful for sequence prediction tasks, where each step depends on the previous steps.
#
# 5. **Autoencoders**: These are unsupervised learning algorithms that learn efficient codings of input data, often used for dimensionality reduction.
#
# 6. **Generative Adversarial Networks (GANs)**: These consist of two neural networks: a generator and a discriminator, where the generator creates new data samples, and the discriminator tries to distinguish between real and fake data.
#
# 7. **
# User: thankyou
# Chatbot: Thinking...
# Chatbot: You're welcome! If you have any more questions, feel free to ask.
# User: exit
# Chatbot: Goodbye! Have a great day.
